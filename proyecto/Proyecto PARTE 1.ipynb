# %%
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import pandas as pd
import numpy as np
import joblib
import pickle


from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from IPython.display import Image
from sklearn.svm import SVC


if tf.__version__.startswith("2."):
    import tensorflow.compat.v1 as tf
    tf.compat.v1.disable_v2_behavior()
    tf.compat.v1.disable_eager_execution()
    print("Enabled compatitility to tf1.x")
# Out:
# WARNING:tensorflow:From C:\Users\Ricar\anaconda3\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Enabled compatitility to tf1.x

# %%
data = pd.read_csv("data_titanic_proyecto.csv")

# %% [markdown]
# ## Analisis de variables

# %%
data.head(5)
# Out:
#    PassengerId                                               Name   Age  \
# 0            1                            Braund, Mr. Owen Harris  22.0
# 1            2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2            3                             Heikkinen, Miss. Laina  26.0
# 3            4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4            5                           Allen, Mr. William Henry  35.0
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked passenger_class  \
# 0      1      0         A/5 21171   7.2500   NaN        S           Lower
# 1      1      0          PC 17599  71.2833   C85        C           Upper
# 2      0      0  STON/O2. 3101282   7.9250   NaN        S           Lower
# 3      1      0            113803  53.1000  C123        S           Upper
# 4      0      0            373450   8.0500   NaN        S           Lower
#
#   passenger_sex passenger_survived
# 0             M                  N
# 1             F                  Y
# 2             F                  Y
# 3             F                  Y
# 4             M                  N

# %% [markdown]
# Se busca eliminar las variables especificas y dejar unicamente las generales

# %%
columns_to_delete = ['PassengerId', 'Name', 'Ticket']
label_column = ['passenger_survived']

data = data.drop(columns=columns_to_delete)

# %%
data.head(5)
# Out:
#     Age  SibSp  Parch     Fare Cabin Embarked passenger_class passenger_sex  \
# 0  22.0      1      0   7.2500   NaN        S           Lower             M
# 1  38.0      1      0  71.2833   C85        C           Upper             F
# 2  26.0      0      0   7.9250   NaN        S           Lower             F
# 3  35.0      1      0  53.1000  C123        S           Upper             F
# 4  35.0      0      0   8.0500   NaN        S           Lower             M
#
#   passenger_survived
# 0                  N
# 1                  Y
# 2                  Y
# 3                  Y
# 4                  N

# %%
data.describe()
# Out:
#               Age       SibSp       Parch        Fare
# count  714.000000  891.000000  891.000000  891.000000
# mean    29.699118    0.523008    0.381594   32.204208
# std     14.526497    1.102743    0.806057   49.693429
# min      0.420000    0.000000    0.000000    0.000000
# 25%     20.125000    0.000000    0.000000    7.910400
# 50%     28.000000    0.000000    0.000000   14.454200
# 75%     38.000000    1.000000    0.000000   31.000000
# max     80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# Revision de nulos para posibles imputaciones

# %%
for col in data.columns:
    cant_nulls = data[col].isna().sum()
    cant_regs = len(data[col])
    print(col)
    print(f'Cantidad de nulos: {cant_nulls}')
    print(f'Porcentage de nulos: {round(cant_nulls/cant_regs*100, 2)}% \n')
# Out:
# Age
# Cantidad de nulos: 177
# Porcentage de nulos: 19.87%
#
# SibSp
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%
#
# Parch
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%
#
# Fare
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%
#
# Cabin
# Cantidad de nulos: 687
# Porcentage de nulos: 77.1%
#
# Embarked
# Cantidad de nulos: 2
# Porcentage de nulos: 0.22%
#
# passenger_class
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%
#
# passenger_sex
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%
#
# passenger_survived
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%

# %% [markdown]
# Para concluir que variables son utiles usare un umbral donde si tiene mas del 10% de nulos, la variable sera sacada del dataset de entrenamietno debido a que hacer una imputacion sobre mas del 20% de la data puede llegar a modificar mucho la distribucion de esta. Bajo este criterio las variables Cabin queda fuera del dataset.

# %%
data = data.drop(columns=['Cabin'])

# %% [markdown]
# Imputacion de valores para variable Age y Embarked

# %%
data['Age'].fillna(int(data['Age'].mean()), inplace = True)
data['Embarked'].fillna(data['Embarked'].value_counts().index[0], inplace = True)

# %%
for col in data.columns:
    cant_nulls = data[col].isna().sum()
    cant_regs = len(data[col])
    print(col)
    print(f'Cantidad de nulos: {cant_nulls}')
    print(f'Porcentage de nulos: {round(cant_nulls/cant_regs*100, 2)}% \n')
# Out:
# Age
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%
#
# SibSp
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%
#
# Parch
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%
#
# Fare
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%
#
# Embarked
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%
#
# passenger_class
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%
#
# passenger_sex
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%
#
# passenger_survived
# Cantidad de nulos: 0
# Porcentage de nulos: 0.0%

# %% [markdown]
# Traduccion de variables categoricas a numericas, esto porque no todos los algoritmos que utilizaremos son capaces de recibir como entrada las categorias directamente como es el caso de los arboles de desion.

# %%
categorical_variables = ['Embarked', 'passenger_class', 'passenger_sex', 'passenger_survived']
dictionaries = {}

for col in categorical_variables:
    values = data[col].unique()
    dictionaries[col] = {'word_to_number': {values[number]: number for number in range(len(values))}}
    data[col] = data[col].apply(lambda x: dictionaries[col]['word_to_number'][x])
dictionaries
# Out:
# {'Embarked': {'word_to_number': {'S': 0, 'C': 1, 'Q': 2}},
#  'passenger_class': {'word_to_number': {'Lower': 0, 'Upper': 1, 'Middle': 2}},
#  'passenger_sex': {'word_to_number': {'M': 0, 'F': 1}},
#  'passenger_survived': {'word_to_number': {'N': 0, 'Y': 1}}}

# %%
data.head(5)
# Out:
#     Age  SibSp  Parch     Fare  Embarked  passenger_class  passenger_sex  \
# 0  22.0      1      0   7.2500         0                0              0
# 1  38.0      1      0  71.2833         1                1              1
# 2  26.0      0      0   7.9250         0                0              1
# 3  35.0      1      0  53.1000         0                1              1
# 4  35.0      0      0   8.0500         0                0              0
#
#    passenger_survived
# 0                   0
# 1                   1
# 2                   1
# 3                   1
# 4                   0

# %% [markdown]
# Revision de distribucion de variables numericas

# %%
for col in data.columns[0:4]:
    print(col.upper())
    plt.hist(data[col])
    plt.show()
# Out:
# AGE
# SIBSP
# PARCH
# FARE

# %% [markdown]
# Particion de los datasets

# %%
X_train, X_later, y_train, y_later = train_test_split(data.iloc[:, 1:-1], data.iloc[:, -1], test_size=0.4, random_state=42)

# %%
X_test, X_validation, y_test, y_validation = train_test_split(X_later, y_later, test_size=0.5, random_state=42)

# %%
X_train.shape, X_test.shape, X_validation.shape, y_train.shape, y_test.shape, y_validation.shape
# Out:
# ((534, 6), (178, 6), (179, 6), (534,), (178,), (179,))

# %%
X_train
# Out:
#      SibSp  Parch      Fare  Embarked  passenger_class  passenger_sex
# 570      0      0   10.5000         0                2              0
# 787      4      1   29.1250         2                0              0
# 74       0      0   56.4958         0                0              0
# 113      1      0    9.8250         0                0              1
# 635      0      0   13.0000         0                2              1
# ..     ...    ...       ...       ...              ...            ...
# 106      0      0    7.6500         0                0              1
# 270      0      0   31.0000         0                1              0
# 860      2      0   14.1083         0                0              0
# 435      1      2  120.0000         0                1              1
# 102      0      1   77.2875         0                1              0
#
# [534 rows x 6 columns]

# %%
X_train
# Out:
#      SibSp  Parch      Fare  Embarked  passenger_class  passenger_sex
# 570      0      0   10.5000         0                2              0
# 787      4      1   29.1250         2                0              0
# 74       0      0   56.4958         0                0              0
# 113      1      0    9.8250         0                0              1
# 635      0      0   13.0000         0                2              1
# ..     ...    ...       ...       ...              ...            ...
# 106      0      0    7.6500         0                0              1
# 270      0      0   31.0000         0                1              0
# 860      2      0   14.1083         0                0              0
# 435      1      2  120.0000         0                1              1
# 102      0      1   77.2875         0                1              0
#
# [534 rows x 6 columns]

# %% [markdown]
# ### Entrenamiento

# %% [markdown]
# utils

# %%
def params_parser(conf_string: str):
    params = conf_string.split('_')
    return {**{'model': params[0], 'plain_conf': conf_string}, **{param.split('=')[0]: param.split('=')[1] for param in params[1:]}}

def save_metrics(csv_name='bitacora.csv', **kwargs):
    df = pd.DataFrame({'plain_conf': [kwargs.get('plain_conf')], 
                       'dataset': [kwargs.get('dataset')],
                       'accuracy': [kwargs.get('accuracy')], 
                       'error': [kwargs.get('error')], 
                       'precision': [kwargs.get('precision')], 
                       'recall': [kwargs.get('recall')], 
                       'f1': [kwargs.get('f1')]})
    temp_read = pd.read_csv(csv_name)
    new_df = pd.concat([temp_read, df])
    new_df.to_csv(csv_name, index=0)
    
def train(conf_string: str, x_train, y_train, x_validation, y_validation):
    params = params_parser(conf_string)
    return eval(params['model'])(x_train, y_train, x_validation, y_validation, params)

def save_model(model_obj, name: str):
    joblib.dump(model_obj, f'experimentos/{name}.pkl')

# %% [markdown]
# ## Decision tree

# %%
def decisiontree(x, y, x_validation, y_validation, params):
    dc = DecisionTreeClassifier(random_state=42, 
                                criterion=params.get('criterion', 'gini'),
                                splitter=params.get('splitter', 'best'),
                                max_depth=int(params.get('maxdepth', None)),
                                min_samples_split=int(params.get('minsamplessplit', 2)))
    dc.fit(np.array(x), np.array(y))
    predictions = dc.predict(np.array(x_validation))
    save_metrics(plain_conf=params['plain_conf'], 
                 dataset=str(list(x.columns))[1:-1],
                 accuracy=accuracy_score(np.array(y_validation), predictions), 
                 error=1-accuracy_score(np.array(y_validation), predictions),
                 precision=precision_score(y_validation, predictions), 
                 recall=recall_score(y_validation, predictions), 
                 f1=f1_score(y_validation, predictions))
    save_model(dc, params['plain_conf'])
    print("Finished")

# %%
test_dt_conf = 'decisiontree_splitter=best_maxdepth=220_minsamplessplit=10_criterion=entropy'
train(test_dt_conf, X_train, y_train, X_validation, y_validation)

# %%
results = pd.read_csv('bitacora.csv')
results

# %% [markdown]
# ## SVM

# %%
def svm(x, y, x_validation, y_validation, params):
    sv = SVC(kernel=params.get('kernel', 'rbf'),
             degree=int(params.get('degree', 3)),
             gamma=params.get('gamma', 'scale'))
    sv.fit(x, y)
    predictions = sv.predict(np.array(x_validation))
    save_metrics(plain_conf=params['plain_conf'], 
                 dataset=str(list(x.columns))[1:-1],
                 accuracy=accuracy_score(np.array(y_validation), predictions), 
                 error=1-accuracy_score(np.array(y_validation), predictions), 
                 precision=precision_score(y_validation, predictions), 
                 recall=recall_score(y_validation, predictions), 
                 f1=f1_score(y_validation, predictions))
    save_model(sv, params['plain_conf'])
    print("Finished")

# %%
test_dt_conf = 'svm_kernel=linear_degree=2_gamma=scale'
train(test_dt_conf, X_train, y_train, X_validation, y_validation)
# Out:
# Finished

# %%
pd.read_csv('bitacora.csv')
# Out:
#                                            plain_conf  \
# 0   decisiontree_splitter=best_maxdepth=100_minsam...
# 1   decisiontree_splitter=best_maxdepth=200_minsam...
# 2   decisiontree_splitter=best_maxdepth=200_minsam...
# 3   decisiontree_splitter=best_maxdepth=200_minsam...
# 4   decisiontree_splitter=best_maxdepth=200_minsam...
# 5   decisiontree_splitter=best_maxdepth=220_minsam...
# 6   decisiontree_splitter=random_maxdepth=220_mins...
# 7   decisiontree_splitter=best_maxdepth=220_minsam...
# 8   decisiontree_splitter=best_maxdepth=220_minsam...
# 9              svm_kernel=linear_degree=4_gamma=scale
# 10             svm_kernel=linear_degree=2_gamma=scale
# 11             svm_kernel=linear_degree=5_gamma=scale
# 12              svm_kernel=linear_degree=5_gamma=auto
# 13                svm_kernel=poly_degree=2_gamma=auto
# 14               svm_kernel=poly_degree=2_gamma=scale
# 15               svm_kernel=poly_degree=5_gamma=scale
# 16                svm_kernel=rbf_degree=5_gamma=scale
# 17            svm_kernel=sigmoid_degree=5_gamma=scale
# 18               svm_kernel=poly_degree=7_gamma=scale
# 19               svm_kernel=poly_degree=2_gamma=scale
# 20             svm_kernel=linear_degree=2_gamma=scale
#
#                                               dataset  accuracy     error  \
# 0   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.782123  0.217877
# 1   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.782123  0.217877
# 2   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.810056  0.189944
# 3   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.782123  0.217877
# 4   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.810056  0.189944
# 5   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.810056  0.189944
# 6   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.765363  0.234637
# 7   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.793296  0.206704
# 8   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.810056  0.189944
# 9   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.798883  0.201117
# 10  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.798883  0.201117
# 11  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.798883  0.201117
# 12  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.798883  0.201117
# 13  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.787709  0.212291
# 14  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.620112  0.379888
# 15  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.614525  0.385475
# 16  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.664804  0.335196
# 17  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.558659  0.441341
# 18  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.620112  0.379888
# 19  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.620112  0.379888
# 20  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.798883  0.201117
#
#     precision    recall        f1
# 0    0.776119  0.684211  0.727273
# 1    0.776119  0.684211  0.727273
# 2    0.800000  0.736842  0.767123
# 3    0.768116  0.697368  0.731034
# 4    0.800000  0.736842  0.767123
# 5    0.800000  0.736842  0.767123
# 6    0.765625  0.644737  0.700000
# 7    0.800000  0.684211  0.737589
# 8    0.800000  0.736842  0.767123
# 9    0.794118  0.710526  0.750000
# 10   0.794118  0.710526  0.750000
# 11   0.794118  0.710526  0.750000
# 12   0.794118  0.710526  0.750000
# 13   0.865385  0.592105  0.703125
# 14   0.900000  0.118421  0.209302
# 15   1.000000  0.092105  0.168675
# 16   0.863636  0.250000  0.387755
# 17   0.480000  0.473684  0.476821
# 18   1.000000  0.105263  0.190476
# 19   0.900000  0.118421  0.209302
# 20   0.794118  0.710526  0.750000

# %% [markdown]
# ## Naive Bayes

# %%
class NaiveModel():
    def __init__(self):
        self.true_frequencies = {}
        self.false_frequencies = {}

    def fit(self, x_train, y_train):
        true_registers = x_train[y_train==1]
        false_registers = x_train[y_train==0]

        true_prior = len(true_registers)/len(x_train)
        false_prior = len(false_registers)/len(x_train)

        self.true_frequencies = {col:{index: row[0]/len(true_registers) for index, row in  pd.DataFrame(true_registers[col].value_counts()).iterrows()} for col in true_registers.columns}
        self.false_frequencies = {col:{index: row[0]/len(false_registers) for index, row in  pd.DataFrame(false_registers[col].value_counts()).iterrows()} for col in false_registers.columns}

    def predict(self, x):

        positive_predictions = x.apply(lambda row: np.prod([self.true_frequencies[col].get(row[col], 0.001) for col in x.columns]), axis=1)
        negative_predictions = x.apply(lambda row: np.prod([self.false_frequencies[col].get(row[col], 0.001) for col in x.columns]), axis=1)

        return (positive_predictions > negative_predictions) * 1

def naivebayes(x, y, x_validation, y_validation, params):
    params['features'] = [x.columns[int(col_index)] for col_index in params['features'].split(',')]
    x_train = x[params['features']]
    x_validation = x_validation[params['features']]
    
    nv = NaiveModel()
    nv.fit(x_train, y)
    predictions = nv.predict(x_validation)
    save_metrics(plain_conf=params['plain_conf'], 
                 dataset=str(list(x_train.columns))[1:-1],
                 accuracy=accuracy_score(np.array(y_validation), predictions), 
                 error=1-accuracy_score(np.array(y_validation), predictions),
                 precision=precision_score(y_validation, predictions), 
                 recall=recall_score(y_validation, predictions), 
                 f1=f1_score(y_validation, predictions))
    save_model(nv, params['plain_conf'])
    print('Finished')

# %%
test_dt_conf = 'naivebayes_features=0,4,5'
train(test_dt_conf, X_train, y_train, X_validation, y_validation)
# Out:
# ['SibSp', 'passenger_class', 'passenger_sex']
# Finished

# %%
pd.read_csv('bitacora.csv').tail(10)
# Out:
#                      plain_conf  \
# 23  naivebayes_features=0,1,3,4
# 24  naivebayes_features=0,1,4,5
# 25  naivebayes_features=0,3,4,5
# 26  naivebayes_features=1,3,4,5
# 27    naivebayes_features=3,4,5
# 28  naivebayes_features=0,3,4,5
# 29  naivebayes_features=0,3,4,5
# 30    naivebayes_features=0,4,5
# 31      naivebayes_features=0,5
# 32    naivebayes_features=0,4,5
#
#                                               dataset  accuracy     error  \
# 23    'SibSp', 'Parch', 'Embarked', 'passenger_class'  0.698324  0.301676
# 24  'SibSp', 'Parch', 'passenger_class', 'passenge...  0.793296  0.206704
# 25  'SibSp', 'Embarked', 'passenger_class', 'passe...  0.810056  0.189944
# 26  'Parch', 'Embarked', 'passenger_class', 'passe...  0.798883  0.201117
# 27     'Embarked', 'passenger_class', 'passenger_sex'  0.798883  0.201117
# 28  'SibSp', 'Embarked', 'passenger_class', 'passe...  0.810056  0.189944
# 29  'SibSp', 'Embarked', 'passenger_class', 'passe...  0.810056  0.189944
# 30        'SibSp', 'passenger_class', 'passenger_sex'  0.815642  0.184358
# 31                           'SibSp', 'passenger_sex'  0.798883  0.201117
# 32        'SibSp', 'passenger_class', 'passenger_sex'  0.815642  0.184358
#
#     precision    recall        f1
# 23   0.634146  0.684211  0.658228
# 24   0.746835  0.776316  0.761290
# 25   0.750000  0.828947  0.787500
# 26   0.756410  0.776316  0.766234
# 27   0.756410  0.776316  0.766234
# 28   0.750000  0.828947  0.787500
# 29   0.750000  0.828947  0.787500
# 30   0.786667  0.776316  0.781457
# 31   0.794118  0.710526  0.750000
# 32   0.786667  0.776316  0.781457

# %% [markdown]
# ## Logistic Regression

# %%
Image('lg_graph.png')

# %%
class LogisticClassificator():
    def __init__(self, w, b):
        self.w = w
        self.b = b
        
    def predict(self, x):
        x = np.array(x).astype(np.float32)

        with tf.Graph().as_default():
            weights = tf.constant(self.w)
            biases = tf.constant(self.b)
            x_ = tf.constant(x)

            prediction = tf.round(tf.sigmoid(tf.matmul(x_, weights)+biases))
            init = tf.global_variables_initializer()

            with tf.compat.v1.Session() as session:
                init = tf.global_variables_initializer()
                predictions = prediction.eval()
                return predictions.reshape(-1)

def lg(x, y, x_validation, y_validation, params):
    batch_size = int(params['batchsize'])
    epochs = int(params['epochs'])
    reg_factor = float(params['regfactor'])
    verbose = int(params['verbose'])
    lr = float(params['lr'])
    columns = x.columns
    
    params['features'] = [x.columns[int(col_index)] for col_index in params['features'].split(',')]
    x = x[params['features']]
    x  = np.array(x).astype(np.float32)
    
    x_validation = x_validation[params['features']]
    x_validation = np.array(x_validation).astype(np.float32)
    
    def mini_batches(x, y, batch_size):
        for batch_iteration in range(int(len(x)/batch_size)):
            init_batch = batch_iteration * batch_size
            end_batch = init_batch + batch_size
            yield np.array(x[init_batch:end_batch]), np.array(y[init_batch:end_batch])
    
    def accuracy(predictions, labels):
        return (np.sum((predictions == labels) * 1)/len(predictions)) * 100            
    
    graph = tf.Graph()
    with graph.as_default():
        x_train = tf.placeholder(tf.float32, shape=(batch_size, x.shape[1]))
        y_train = tf.placeholder(tf.float32, shape=(batch_size, 1))
        x_validation = tf.constant(x_validation)
        y_validation = tf.constant(y_validation)
        
        alpha = tf.placeholder(tf.float32)
        weights = tf.Variable(tf.truncated_normal([x.shape[1], 1]))
        biases = tf.Variable(tf.zeros(1))
        regularization = tf.nn.l2_loss(weights)
        
        logits = tf.matmul(x_train, weights) + biases
        loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=logits, labels=y_train)) + (alpha*regularization)
        optimizer = tf.train.GradientDescentOptimizer(lr).minimize(loss)
        
        train_prediction = tf.round(tf.sigmoid(logits))
        valid_prediction = tf.round(tf.sigmoid(tf.matmul(x_validation, weights)+biases))
        
        error = tf.summary.scalar("error", loss)
        init = tf.global_variables_initializer()
        
    with tf.Session(graph=graph) as session:
        session.run(init)
        writer = tf.summary.FileWriter(f"./experimentos_tf/{params['plain_conf']}", session.graph)
        for epoch in range(epochs):
            for mini_x, mini_y in mini_batches(x, y, batch_size):
                feed_dict = {x_train:mini_x, y_train:mini_y , alpha : reg_factor }
                opt, lo, predictions =  session.run([optimizer,loss,train_prediction],feed_dict= feed_dict)
             
            if (epoch + 1) % verbose == 0:
                print(f"Validation accuracy at epoch {epoch}: {accuracy(valid_prediction.eval(), y_validation.eval())}")
                
                writer.add_summary(session.run(error, feed_dict= feed_dict), epoch)
        
        w_to_save = np.array(weights.eval())
        biases_to_save = np.array(biases.eval())
        params_to_save = np.array([w_to_save, biases_to_save])
        np.save(f"experimentos/{params['plain_conf']}.npy", params_to_save)
        
        predictions = valid_prediction.eval()
        labels = y_validation.eval()

        save_metrics(plain_conf=params['plain_conf'], 
                 dataset=str(list(columns))[1:-1],
                 accuracy=accuracy_score(labels, predictions), 
                 error=1-accuracy_score(labels, predictions),
                 precision=precision_score(labels, predictions), 
                 recall=recall_score(labels, predictions), 
                 f1=f1_score(labels, predictions))

    print("Finished")

# %%
test_dt_conf = "lg_batchsize=32_epochs=900_regfactor=0.01_verbose=1000_lr=0.001_features=0,3,4,5"
train(test_dt_conf, X_train, y_train[:,None].astype(np.float32), X_validation, y_validation[:,None].astype(np.float32))
# Out:
# <ipython-input-123-441594d0acb1>:2: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   train(test_dt_conf, X_train, y_train[:,None].astype(np.float32), X_validation, y_validation[:,None].astype(np.float32))
# Finished
# <ipython-input-106-b73a7e2bb683>:62: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   params_to_save = np.array([w_to_save, biases_to_save])

# %% [markdown]
# Error durante el entramiento del mejor modelo

# %%
Image('best_lg.png')

# %%
pd.read_csv('bitacora.csv')
# Out:
#                                            plain_conf  \
# 0   decisiontree_splitter=best_maxdepth=100_minsam...
# 1   decisiontree_splitter=best_maxdepth=200_minsam...
# 2   decisiontree_splitter=best_maxdepth=200_minsam...
# 3   decisiontree_splitter=best_maxdepth=200_minsam...
# 4   decisiontree_splitter=best_maxdepth=200_minsam...
# 5   decisiontree_splitter=best_maxdepth=220_minsam...
# 6   decisiontree_splitter=random_maxdepth=220_mins...
# 7   decisiontree_splitter=best_maxdepth=220_minsam...
# 8   decisiontree_splitter=best_maxdepth=220_minsam...
# 9              svm_kernel=linear_degree=4_gamma=scale
# 10             svm_kernel=linear_degree=2_gamma=scale
# 11             svm_kernel=linear_degree=5_gamma=scale
# 12              svm_kernel=linear_degree=5_gamma=auto
# 13                svm_kernel=poly_degree=2_gamma=auto
# 14               svm_kernel=poly_degree=2_gamma=scale
# 15               svm_kernel=poly_degree=5_gamma=scale
# 16                svm_kernel=rbf_degree=5_gamma=scale
# 17            svm_kernel=sigmoid_degree=5_gamma=scale
# 18               svm_kernel=poly_degree=7_gamma=scale
# 19               svm_kernel=poly_degree=2_gamma=scale
# 20             svm_kernel=linear_degree=2_gamma=scale
# 21                      naivebayes_features=0,1,3,4,5
# 22                        naivebayes_features=0,1,3,4
# 23                        naivebayes_features=0,1,3,4
# 24                        naivebayes_features=0,1,4,5
# 25                        naivebayes_features=0,3,4,5
# 26                        naivebayes_features=1,3,4,5
# 27                          naivebayes_features=3,4,5
# 28                        naivebayes_features=0,3,4,5
# 29                        naivebayes_features=0,3,4,5
# 30                          naivebayes_features=0,4,5
# 31                            naivebayes_features=0,5
# 32                          naivebayes_features=0,4,5
# 33  lg_batchsize=60_epochs=20_regfactor=0.001_verb...
# 34  lg_batchsize=60_epochs=20_regfactor=0.001_verb...
# 35  lg_batchsize=60_epochs=20_regfactor=0.001_verb...
# 36  lg_batchsize=32_epochs=50_regfactor=0.001_verb...
# 37  lg_batchsize=32_epochs=50_regfactor=0.01_verbo...
# 38  lg_batchsize=32_epochs=50_regfactor=0.001_verb...
# 39  lg_batchsize=32_epochs=50_regfactor=0.001_verb...
# 40  lg_batchsize=32_epochs=150_regfactor=0.001_ver...
# 41  lg_batchsize=32_epochs=150_regfactor=0.001_ver...
# 42  lg_batchsize=32_epochs=350_regfactor=0.001_ver...
# 43  lg_batchsize=32_epochs=500_regfactor=0.001_ver...
# 44  lg_batchsize=64_epochs=500_regfactor=0.001_ver...
# 45  lg_batchsize=16_epochs=500_regfactor=0.001_ver...
# 46  lg_batchsize=16_epochs=500_regfactor=0.001_ver...
# 47  lg_batchsize=32_epochs=500_regfactor=0.001_ver...
# 48  lg_batchsize=32_epochs=500_regfactor=0.001_ver...
# 49  lg_batchsize=32_epochs=500_regfactor=0.001_ver...
# 50  lg_batchsize=32_epochs=500_regfactor=0.001_ver...
# 51  lg_batchsize=32_epochs=500_regfactor=0.001_ver...
# 52  lg_batchsize=32_epochs=500_regfactor=0.001_ver...
# 53  lg_batchsize=32_epochs=500_regfactor=0.001_ver...
# 54  lg_batchsize=32_epochs=600_regfactor=0.001_ver...
# 55  lg_batchsize=32_epochs=700_regfactor=0.01_verb...
# 56  lg_batchsize=32_epochs=700_regfactor=0.01_verb...
# 57  lg_batchsize=32_epochs=800_regfactor=0.01_verb...
# 58  lg_batchsize=32_epochs=900_regfactor=0.01_verb...
#
#                                               dataset  accuracy     error  \
# 0   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.782123  0.217877
# 1   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.782123  0.217877
# 2   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.810056  0.189944
# 3   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.782123  0.217877
# 4   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.810056  0.189944
# 5   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.810056  0.189944
# 6   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.765363  0.234637
# 7   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.793296  0.206704
# 8   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.810056  0.189944
# 9   'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.798883  0.201117
# 10  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.798883  0.201117
# 11  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.798883  0.201117
# 12  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.798883  0.201117
# 13  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.787709  0.212291
# 14  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.620112  0.379888
# 15  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.614525  0.385475
# 16  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.664804  0.335196
# 17  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.558659  0.441341
# 18  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.620112  0.379888
# 19  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.620112  0.379888
# 20  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.798883  0.201117
# 21  'SibSp', 'Parch', 'Embarked', 'passenger_class...  0.782123  0.217877
# 22    'SibSp', 'Parch', 'Embarked', 'passenger_class'  0.698324  0.301676
# 23    'SibSp', 'Parch', 'Embarked', 'passenger_class'  0.698324  0.301676
# 24  'SibSp', 'Parch', 'passenger_class', 'passenge...  0.793296  0.206704
# 25  'SibSp', 'Embarked', 'passenger_class', 'passe...  0.810056  0.189944
# 26  'Parch', 'Embarked', 'passenger_class', 'passe...  0.798883  0.201117
# 27     'Embarked', 'passenger_class', 'passenger_sex'  0.798883  0.201117
# 28  'SibSp', 'Embarked', 'passenger_class', 'passe...  0.810056  0.189944
# 29  'SibSp', 'Embarked', 'passenger_class', 'passe...  0.810056  0.189944
# 30        'SibSp', 'passenger_class', 'passenger_sex'  0.815642  0.184358
# 31                           'SibSp', 'passenger_sex'  0.798883  0.201117
# 32        'SibSp', 'passenger_class', 'passenger_sex'  0.815642  0.184358
# 33  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.597765  0.402235
# 34  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.653631  0.346369
# 35  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.424581  0.575419
# 36  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.575419  0.424581
# 37  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.715084  0.284916
# 38  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.642458  0.357542
# 39  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.642458  0.357542
# 40  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.815642  0.184358
# 41  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.636872  0.363128
# 42  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.787709  0.212291
# 43  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.770950  0.229050
# 44  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.569832  0.430168
# 45  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.726257  0.273743
# 46  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.770950  0.229050
# 47  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.815642  0.184358
# 48  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.547486  0.452514
# 49  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.603352  0.396648
# 50  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.715084  0.284916
# 51  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.815642  0.184358
# 52  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.597765  0.402235
# 53  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.798883  0.201117
# 54  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.804469  0.195531
# 55  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.692737  0.307263
# 56  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.804469  0.195531
# 57  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.810056  0.189944
# 58  'SibSp', 'Parch', 'Fare', 'Embarked', 'passeng...  0.810056  0.189944
#
#     precision    recall        f1
# 0    0.776119  0.684211  0.727273
# 1    0.776119  0.684211  0.727273
# 2    0.800000  0.736842  0.767123
# 3    0.768116  0.697368  0.731034
# 4    0.800000  0.736842  0.767123
# 5    0.800000  0.736842  0.767123
# 6    0.765625  0.644737  0.700000
# 7    0.800000  0.684211  0.737589
# 8    0.800000  0.736842  0.767123
# 9    0.794118  0.710526  0.750000
# 10   0.794118  0.710526  0.750000
# 11   0.794118  0.710526  0.750000
# 12   0.794118  0.710526  0.750000
# 13   0.865385  0.592105  0.703125
# 14   0.900000  0.118421  0.209302
# 15   1.000000  0.092105  0.168675
# 16   0.863636  0.250000  0.387755
# 17   0.480000  0.473684  0.476821
# 18   1.000000  0.105263  0.190476
# 19   0.900000  0.118421  0.209302
# 20   0.794118  0.710526  0.750000
# 21   0.728395  0.776316  0.751592
# 22   0.634146  0.684211  0.658228
# 23   0.634146  0.684211  0.658228
# 24   0.746835  0.776316  0.761290
# 25   0.750000  0.828947  0.787500
# 26   0.756410  0.776316  0.766234
# 27   0.756410  0.776316  0.766234
# 28   0.750000  0.828947  0.787500
# 29   0.750000  0.828947  0.787500
# 30   0.786667  0.776316  0.781457
# 31   0.794118  0.710526  0.750000
# 32   0.786667  0.776316  0.781457
# 33   0.515625  0.868421  0.647059
# 34   0.558333  0.881579  0.683673
# 35   0.404255  0.750000  0.525346
# 36   0.500000  0.342105  0.406250
# 37   0.735849  0.513158  0.604651
# 38   0.928571  0.171053  0.288889
# 39   0.642857  0.355263  0.457627
# 40   0.841270  0.697368  0.762590
# 41   0.593220  0.460526  0.518519
# 42   0.779412  0.697368  0.736111
# 43   0.769231  0.657895  0.709220
# 44   0.485714  0.223684  0.306306
# 45   0.829268  0.447368  0.581197
# 46   0.727273  0.736842  0.732026
# 47   0.820896  0.723684  0.769231
# 48   0.450980  0.302632  0.362205
# 49   0.558140  0.315789  0.403361
# 50   0.711864  0.552632  0.622222
# 51   0.864407  0.671053  0.755556
# 52   0.529412  0.473684  0.500000
# 53   0.794118  0.710526  0.750000
# 54   0.825397  0.684211  0.748201
# 55   0.596330  0.855263  0.702703
# 56   0.815385  0.697368  0.751773
# 57   0.818182  0.710526  0.760563
# 58   0.818182  0.710526  0.760563

# %% [markdown]
# ## K Folds

# %% [markdown]
# Ya que conocemos la forma basica en la que se separan los sets de entrenamiento para un modelo (train, test). Cuando entrenamos sobre el set de train y hacemos validacion hasta la ultima etapa del entranamiento con el set de test.
#
# Al hacer este tipo de practica estamos de cierta forma sesgando el modelo al set de datos de entrenamiento, es decir estamos sobre ajustando el modelo a que se aprenda el set de entrenamiento al punto de poder responder bien o con poco error los valores esperados del set de entrenamiento. Cuando llegamos a una etapa de test, nuestro modelo al estar sesgado por la data de entrenamiento vemos que tiene una varianza alta ya que el performance del modelo en validacion no sera tan bueno como lo fue en entrenamiento.
#
# Por medio de la tecnica de Kfolds podemos evitar un poco esto, ya que es una tecnica en la cual para entrenar utilizamos todo el set de datos, es decir train y validacion. La forma en la que funciona K folds es que definimos un numero K que significa el tamano en el que haremos subsets de datos para el entrenamiento, ya que el set de datos esta separado en K conjuntos, el modelo se entrena con todas las combinaciones K-1 conjuntos dejando siempre un fold para validacion.
#
# A continuacion un ejemplo:
# Se tiene un dataset de 1000 registros, definimos nuestro k folds con un k = 5, por lo que tendremos 5 sets de datos de 200 registros cada uno.
#
# El modelo ya no se ajustaria unicamente sobre un set de datos sino que se ajustaria 5 veces:
# 1. La primera iterarcion se haria el entrenamiento con los folds 1, 2, 3, 4 y el set de validacion seria el 5.
# 2. La segunda iteracion se haria el entranamiento con los folds 1, 2, 3, 5 y el set de validacion seria el 4.
# 3. La segunda iteracion se haria el entranamiento con los folds 1, 2, 4, 5 y el set de validacion seria el 3.
# 4. La segunda iteracion se haria el entranamiento con los folds 1, 3, 4, 5 y el set de validacion seria el 2.
# 5. La segunda iteracion se haria el entranamiento con los folds 2, 3, 4, 5 y el set de validacion seria el 1.
#
# Las metrica de validacion ahora ya no seria sobre el dataset de entramiento completo sino que seria un promedio de los resultados de cada entranamiento que se dio con cada combinacion de folds.
#
# Con estos logramos que el modelo se entrene mas generalizado ya que cada registro del set de datos tuvo la oportunidad de aportar un poco al entrenamiento del modelo. Por medio de este metodo podemos reducir el sesgo ya que el modelo pudo absorver todos los patrones representados por el set completo de datos y la varianza se reducira por la generalizacion que obtiene el modelo.

# %% [markdown]
# ## Prueba Evaluacion Final

# %% [markdown]
# Predecir set de test sobre los mejores modelos

# %%
def load_decision_tree(conf):
        return joblib.load(f"experimentos/{conf}.pkl")

def load_svm(conf):
    return joblib.load(f"experimentos/{conf}.pkl")

def load_naive(conf):
    return joblib.load(f"experimentos/{conf}.pkl")

def load_lg(conf):
    pr = np.load(f"experimentos/{conf}.npy", allow_pickle=True)
    return LogisticClassificator(pr[0], pr[1])

# Loading Models and setting datasets according to selected features during training

dt_model = load_decision_tree('decisiontree_splitter=best_maxdepth=220_minsamplessplit=10_criterion=entropy')
svm_model = load_svm('svm_kernel=linear_degree=2_gamma=scale')
naive_model = load_naive('naivebayes_features=0,4,5')
lg_model = load_lg('lg_batchsize=32_epochs=900_regfactor=0.01_verbose=1000_lr=0.001_features=0,3,4,5')

x_dt = X_test
x_svm = X_test
x_naive = X_test[["SibSp", "passenger_class", "passenger_sex"]]
x_lg = X_test[["SibSp", "Embarked", "passenger_class", "passenger_sex"]]

# Predictions over X test set

dt_predictions = dt_model.predict(x_dt)
svm_predictions = svm_model.predict(x_svm)
naive_predictions = naive_model.predict(x_naive)
lg_predictions = lg_model.predict(x_lg)

# %% [markdown]
# Combinar resultados por medio e la moda

# %%
def most_popular_prediction(pred1, pred2, pred3, pred4):
    matrix_predictions = np.array([pred1, pred2, pred3, pred4])
    sum_predictions = np.sum(matrix_predictions, axis=0)
    return (sum_predictions >= 2) * 1
    
combined_predictions = most_popular_prediction(dt_predictions, svm_predictions, naive_predictions, lg_predictions)

# %% [markdown]
# Crear tabla de predicciones

# %%
df_predictions = pd.DataFrame({'decision_tree': dt_predictions, 
                              'svm_predictions': svm_predictions, 
                              'naive_predictions': naive_predictions,
                              'logistic_predictions': lg_predictions,
                              'combined_predictions': combined_predictions})

df_predictions.head(5)
# Out:
#      decision_tree  svm_predictions  naive_predictions  logistic_predictions  \
# 849              1                1                  1                   1.0
# 331              0                0                  0                   0.0
# 260              0                0                  0                   0.0
# 316              1                1                  1                   1.0
# 292              1                0                  0                   0.0
#
#      combined_predictions
# 849                     1
# 331                     0
# 260                     0
# 316                     1
# 292                     0

# %% [markdown]
# Metricas de evaluacion sobre predicciones combinadas

# %%
accuracy = accuracy_score(y_test, combined_predictions)
precision = precision_score(y_test, combined_predictions)
recall = recall_score(y_test, combined_predictions)
f1 = f1_score(y_test, combined_predictions)

# %% [markdown]
# Tabla de metricas finales del modelo ensamblado

# %%
final_metrics = pd.DataFrame({'accuracy': [accuracy], 'precision': [precision], 'recall': [recall], 'f1': [f1]})
final_metrics
# Out:
#    accuracy  precision    recall        f1
# 0  0.820225   0.770492  0.723077  0.746032

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# El hacer un modelo ensamblado a partir de diferentes modelos es un tema que talvez no se ha mencionado mucho sino que se han desarrolado modelos de ensamblado del mismo tipo de modelos "torpes" pero la verdad es que con este proyecto se demuestra que es posible y que hay un tema mas de retoque en cuanto a que talvez de esta forma si queremos mejorar cierta metrica y el modelo que estamos usando no nos esta funcionando, puede que otro tipo de modelos nos ayude a mejorar en este tema sin dejar de lado que otro modelo nos ayude en otra metrica, al final es una prediccion colectiva por lo que ya no solo los hyperparametros de un modelo entrarn en juego, ahora tenemos una poblacion mas grande de hyperparametros que nos pueden ayudar a disminuir errores o a aumentar exactitud.
#
# Sin duda un tema en este tipo de modelo sera que modelos utilizara para hacer el ensamblaje, pues ya hay disponibles varios modelos pero creo que tocaria tener mas en mente aquellos modelos que tienen cierta fama de ser buenos para X cosa, o son buenos para aumentar el recall o los qeu son buenos para tenes una exactitud alta. Creo que para llegar a generar un modelo de esta forma se debe de tener mucho en cuenta y ser un poco experto ya en cada uno de los modelo, no solo teoricamente sino tambien tencnico pues en este proyecto hubieron 2 modelos desarrollados con la libreria de scikit learn, 1 desarrollado a mano con sumpy y otro con Tensorflow, por lo que integrarlos es un poco complejo o trabajoso tecnicamente.
